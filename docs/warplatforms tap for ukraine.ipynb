# %% [markdown]
# # WARPLATFORMS - TAP FOR UKRAINE

# %% [markdown]
# ### BEFORE

# %% [markdown]
# ![tap_project_plan.jpg](attachment:tap_project_plan.jpg)

# %% [markdown]
# ## AFTER

# %% [markdown]
# <img src="data:image/jpeg;base64,...">

# %% [markdown]
# ## Docker-Compose Creator
# Una shell interattiva che permette di gestire i container del progetto, visualizzare e modificare le loro configurarizioni, dialogare con docker e creare dinamicamente un un numero arbitrario di container per il fetching dei messaggi da Telegram.

# %% [markdown]
# ![0_JWamM6EAaWMQFlcA.jpg](attachment:0_JWamM6EAaWMQFlcA.jpg)

# %% [markdown]
# ![creator_libs.PNG](attachment:creator_libs.PNG)

# %% [markdown]
# Utiliziamo:<br>
#     <ol>
#     <li><b>Config</b> parser per gestire il config.ini</li>
#     <li><b>Docker</b> per dialogare con il docker daemon</li>
#     <li><b>Subprocess</b> Per eseguire comandi, come da shell.</li>
#     <li><b>Sys</b> per gestire la terminazione del processo</li>
#     <li><b>Json</b> per il json</li>
#     <li><b>Threading</b> per avviare un thread che effettua una serie di azioni e controlli in background</li>
#     <li><b>Time</b> per gestire vari delay</li>
#     </ol>

# %% [markdown]
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Configurazione per i canali telegram

# %% [markdown]
# <img src="data:image/png;base64,..." alt="immagine">

# %% [markdown]
# ## Scraping

# %% [markdown]
# <img src="data:image/jpeg;base64,...">

# %% [markdown]
# ## Traduttori

# %% [markdown]
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Logstash
# Il primo componente dello stack ELK

# %% [markdown]
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Kafka

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Spark

# %% [markdown]
# ![TAP%20for%20Ukraine%20%283%29.png](attachment:TAP%20for%20Ukraine%20%283%29.png)

# %% [markdown]
# ![Spark%20Streaming%20pipeline.png](attachment:Spark%20Streaming%20pipeline.png)

# %% [markdown]
# ![pyspark_modules_udf.PNG](attachment:pyspark_modules_udf.PNG)

# %% [markdown]
# ## URL detection and scraping

# %%
from urlScraper import findAllUrls,loadAndParse,cleanText


print(findAllUrls(input("Testo>")))

#https://github.com/tapunict/warplatforms/blob/main/README.md
print(loadAndParse(input("Un URL>"))[1830:])
# Out:
# Testo>okkood ee..o
# []
# Un URL>https://github.com/tapunict/warplatforms/blob/main/README.md
# [LOAD AND PARSE] https://github.com/tapunict/warplatforms/blob/main/README.md
#
# Loading https://github.com/tapunict/warplatforms/blob/main/README.md ...
# C:\Users\Lorenzo\anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...

# %% [markdown]
# ## Whois

# %% [markdown]
# ![whois_code.PNG](attachment:whois_code.PNG)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Sentiment Analysis with Spark ML

# %% [markdown]
# ![spark_ml_getmodel-2.PNG](attachment:spark_ml_getmodel-2.PNG)

# %% [markdown]
# #### Controlla se esiste un modello già pronto e, in tal caso, lo ritorna.
# #### Altrimenti esegue la sequenza di stage(3 Transformer e un Estimator) sul Training Set (Fit)

# %% [markdown]
# ### Pipeline:

# %% [markdown]
# ![getPipeline.PNG](attachment:getPipeline.PNG)

# %% [markdown]
# ### Dopo aver ottenuto il modello, effettuiamo la Transform per ottenere le predizioni
# ### Creiamo una colonna e applichiamo l'udf precedentemente definito sulla colonna delle predizioni

# %% [markdown]
# ![pipeline_transform.PNG](attachment:pipeline_transform.PNG)

# %% [markdown]
# ![Immagine%202022-06-19%20154539.png](attachment:Immagine%202022-06-19%20154539.png)

# %% [markdown]
# ## Il nostro modello ha le idee chiare anche sulla guerra.

# %% [markdown]
# ![7.png](attachment:7.png)

# %% [markdown]
# ## Geocoding

# %% [markdown]
# Abbiamo effettuato delle chiamate alle API di back4app per ottenere un dataset con delle informazioni sulle città ucraine.(<b style="color:darkgreen">FetchDataset</b>)<br>
# Tale dataset in seguito è stato adattato ai nostri scopi. (<b style="color:darkgreen">modifyDataset</b>)

# %% [markdown]
# ![geocoding_getting_dataset.PNG](attachment:geocoding_getting_dataset.PNG)

# %% [markdown]
# Uno dei due dataframe definiti in pyspark popolerà due colonne con le funzioni <b style="color:darkgreen">finCitiesInText</b> e <b style="color:darkgreen">getLocationAsString</b>.
# Utilizzeremo i geopoints ottenuti tramite <b style="color:darkgreen">getLocationAsString</b> per visualizzazione su Kibana una heatmap delle città più citate nei messaggi.

# %% [markdown]
# ![geocoding_find_cities.PNG](attachment:geocoding_find_cities.PNG)

# %% [markdown]
# ## Elasticsearch

# %% [markdown]
# ## Kibana

# %% [markdown]
# ![TAP%20for%20Ukraine%20%284%29.png](attachment:TAP%20for%20Ukraine%20%284%29.png)

# %% [markdown]
# ![6.png](attachment:6.png)

# %% [markdown]
# ![dashboard.png](attachment:dashboard.png)
